# %%
import random

# %%
import random

def f(x):
    return (x - 3) ** 2 + 4

def dx_f(x):
    return 2 * (x - 3)

L = 0.001
iterations = 10

x = random.randint(-15, 15)

# %%
X =

# %%
print("시작 x:", x)

for i in range(iterations):
    d_x = dx_f(x)
    x -= L * d_x
    print(f"{i+1}번째 반복: x = {x}, f(x) = {f(x)}")
# Out:
# 시작 x: 15
# 1번째 반복: x = 14.976, f(x) = 147.42457600000003
# 2번째 반복: x = 14.952048000000001, f(x) = 146.85145139430404
# 3번째 반복: x = 14.928143904, f(x) = 146.28061699453238
# 4번째 반복: x = 14.904287616192, f(x) = 145.7120636490222
# 5번째 반복: x = 14.880479040959617, f(x) = 145.14578224268075
# 6번째 반복: x = 14.856718082877698, f(x) = 144.581763696839
# 7번째 반복: x = 14.833004646711943, f(x) = 144.01999896910644
# 8번째 반복: x = 14.80933863741852, f(x) = 143.4604790532259
# 9번째 반복: x = 14.785719960143682, f(x) = 142.9031949789292
# 10번째 반복: x = 14.762148520223395, f(x) = 142.3481378117934
